# %%
import numpy as np
import pandas as pd

# %%
ds = pd.read_csv('AmesHousing.csv')

# %%
ds.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
ds.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v1 = ds['Gr Liv Area']
y = ds['SalePrice']
plt.scatter(v1,y)
plt.title('General Living Area vs Sale Price')
plt.xlabel('Gr Liv Area')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Lot Frontage']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' Lot Frontage vs Sale Price')
plt.xlabel('Lot Frontage')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['PID']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' Lot Area vs Sale Price')
plt.xlabel('Lot Area')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Overall Cond']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Overall Cond vs Sale Price')
plt.xlabel('Overall Cond')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Year Built']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Year Built vs Sale Price')
plt.xlabel('Year Built')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Year Remod/Add']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Year Remod/Add vs Sale Price')
plt.xlabel('Year Remod/Add')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Mas Vnr Area']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Mas Vnr Type vs Sale Price')
plt.xlabel('Mas Vnr Type')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Total Bsmt SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Total Bsmt SF  vs Sale Price')
plt.xlabel('Total Bsmt SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Misc Val']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Misc Val vs Sale Price')
plt.xlabel('Misc Val')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Neighborhood']
y = ds['SalePrice']
plt.scatter(y,v2)
plt.title('Neighborhood vs Sale Price')
plt.xlabel('SalePrice')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
avgPrice = np.mean(ds['SalePrice'])
print(avgPrice)
# Out:
# 180796.0600682594

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Overall Qual']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Overall Qual vs Sale Price')
plt.xlabel('Overall Qual')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['BsmtFin SF 1']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('BsmtFin SF 1 vs Sale Price')
plt.xlabel('BsmtFin SF1')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['BsmtFin SF 2']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('BsmtFin SF 2 vs Sale Price')
plt.xlabel('BsmtFin SF 2')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Bsmt Unf SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Bsmt Unf SF vs Sale Price')
plt.xlabel('Bsmt Unf SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['1st Flr SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' 1st Flr SF vs Sale Price')
plt.xlabel('1st Flr SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['2nd Flr SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' 2nd Flr SF vs Sale Price')
plt.xlabel('2nd Flr SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Low Qual Fin SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Low Qual Fin SF vs Sale Price')
plt.xlabel('Low Qual Fin SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Bsmt Full Bath']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' Bsmt Full Bath vs Sale Price')
plt.xlabel('Bsmt Full Bath')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Bsmt Half Bath']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' Bsmt Half Bath vs Sale Price')
plt.xlabel('Bsmt Half Bath')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Bedroom AbvGr']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title(' Bedroom AbvGr vs Sale Price')
plt.xlabel('Bedroom AbvGr')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Kitchen AbvGr']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Kitchen AbvGr vs Sale Price')
plt.xlabel('Kitchen AbvGr')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['TotRms AbvGrd']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('TotRms AbvGrd vs Sale Price')
plt.xlabel('TotRms AbvGrd')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Fireplaces']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Fireplaces vs Sale Price')
plt.xlabel('Fireplaces')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Garage Yr Blt']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Garage Yr Blt vs Sale Price')
plt.xlabel('Garage Yr Blt')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Garage Cars']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Garage Cars vs Sale Price')
plt.xlabel('Garage Cars')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Garage Area']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Garage Area vs Sale Price')
plt.xlabel('Garage Area')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Wood Deck SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Wood Deck SF vs Sale Price')
plt.xlabel('Wood Deck SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Open Porch SF']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Open Porch SF vs Sale Price')
plt.xlabel('Open Porch SF')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Enclosed Porch']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Enclosed Porch vs Sale Price')
plt.xlabel('Enclosed Porch')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['3Ssn Porch']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('3Ssn Porch vs Sale Price')
plt.xlabel('3Ssn Porch')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Screen Porch']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Screen Porch vs Sale Price')
plt.xlabel('Screen Porch')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Pool Area']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Pool Area vs Sale Price')
plt.xlabel('Pool Area')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Misc Val']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Misc Val vs Sale Price')
plt.xlabel('Misch Val')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Mo Sold']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Mo Sold vs Sale Price')
plt.xlabel('Mo Sold')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Yr Sold']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Yr Sold vs Sale Price')
plt.xlabel('Yr Sold')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['Sale Condition']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Sale Condition vs Sale Price')
plt.xlabel('Sale Condition')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
v2 = ds['SalePrice']
y = ds['SalePrice']
plt.scatter(v2,y)
plt.title('Sale Price vs Sale Price')
plt.xlabel('Sale Price')
plt.ylabel('SalePrice')
# Out:
# Text(0, 0.5, 'SalePrice')
